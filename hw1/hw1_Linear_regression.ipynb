# %%
import numpy as np
import pandas as pd
import sys
train = pd.read_csv('year1-data.csv')
train2  = pd.read_csv('year2-data.csv')
X_test = pd.read_csv('testing_data.csv')

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
variables = list(train["測項"][:18]) 
X_test_data=[]
for var in variables:
    var_list = []
    print(var)
    for index, row in X_test.iterrows():
        if row["測項"]==var:
            var_list.append(list(row[2:]))
    #var_list shape 366*9
    if var == "PM2.5":
        for i in range(len(var_list)):
            for j in range(len(var_list[0])):
                if str(var_list[i][j])=='nan':
                    var_list[i][j] = 0.0
                if not is_number(var_list[i][j]):
                    for s in var_list[i][j]:
                        if s.isnumeric() or s=='.':
                            pass
                        elif s=='-':
                            var_list[i][j] = 0
                            break
                        else:
                            var_list[i][j] = var_list[i][j].replace(s,"")
        var_ts = np.array(var_list,dtype=float).flatten()
    elif var=="RAINFALL" :
  
        for i in range(len(var_list)):
            for j in range(len(var_list[0])):
                if str(var_list[i][j])=='nan':
                    var_list[i][j] = 0.0
                if is_number(var_list[i][j]):
                    pass
                if var_list[i][j]=='NR':
                    var_list[i][j] = 0.0
                if not is_number(var_list[i][j]):
                    for s in var_list[i][j]:
                        if s.isnumeric() or s=='.':
                            pass
                        elif s=='-':
                            var_list[i][j] = 0
                            break
                        else:
                            var_list[i][j] = var_list[i][j].replace(s,"")                  
        var_ts = np.array(var_list,dtype=float)#shape 50*9
        var_ts = var_ts.flatten() 
    else:
        for i in range(len(var_list)):
            for j in range(len(var_list[0])):
                
                if str(var_list[i][j])=='nan':
                    var_list[i][j] = 0.0
                if not is_number(var_list[i][j]):
                    for s in var_list[i][j]:
                        if s.isnumeric() or s=='.':
                            pass
                        elif s=='-':
                            var_list[i][j] = 0
                            break
                        else:
                            var_list[i][j] = var_list[i][j].replace(s,"")
        var_ts = np.array(var_list,dtype=float)#shape 500*9
        var_ts = var_ts.flatten()#shape 4500*1
    X_test_data.append(var_ts)
X_test_data = np.array(X_test_data,dtype = float)#shape 18*4500


X_for_test=[]

for i in range(0, X_test_data.shape[1],9):
    X_for_test.append(X_test_data[:, i:i+9].flatten())

X_for_test = np.array(X_for_test)#shape 500*162

print(X_for_test.shape)

# %%
variables = list(train["測項"][:18]) 
F=[]
for var in variables:
    var_list = []
    print(var)
    for index, row in train2.iterrows():
        if row["測項"]==var:
            var_list.append(list(row[2:]))
    #var_list shape 366*24 
    if var == "PM2.5":
        for i in range(len(var_list)):
            for j in range(len(var_list[0])):
                if str(var_list[i][j])=='nan':
                    var_list[i][j] = 0.0
                if not is_number(var_list[i][j]):
                    for s in var_list[i][j]:
                        if s.isnumeric() or s=='.':
                            pass
                        elif s=='-':
                            var_list[i][j] = 0
                            break
                        else:
                            var_list[i][j] = var_list[i][j].replace(s,"")
        var_ts = np.array(var_list,dtype=float).flatten()
    elif var=="RAINFALL" :
  
        for i in range(len(var_list)):
            for j in range(len(var_list[0])):
                if str(var_list[i][j])=='nan':
                    var_list[i][j] = 0.0
                if is_number(var_list[i][j]):
                    pass
                if var_list[i][j]=='NR':
                    var_list[i][j] = 0.0
                if not is_number(var_list[i][j]):
                    for s in var_list[i][j]:
                        if s.isnumeric() or s=='.':
                            pass
                        elif s=='-':
                            var_list[i][j] = 0
                            break
                        else:
                            var_list[i][j] = var_list[i][j].replace(s,"")                  
        var_ts = np.array(var_list,dtype=float)#shape 366*24
        var_ts = var_ts.flatten() 
    else:
        for i in range(len(var_list)):
            for j in range(len(var_list[0])):
                
                if str(var_list[i][j])=='nan':
                    var_list[i][j] = 0.0
                if not is_number(var_list[i][j]):
                    for s in var_list[i][j]:
                        if s.isnumeric() or s=='.':
                            pass
                        elif s=='-':
                            var_list[i][j] = 0
                            break
                        else:
                            var_list[i][j] = var_list[i][j].replace(s,"")
        var_ts = np.array(var_list,dtype=float)#shape 366*24
        var_ts = var_ts.flatten()#shape 8784*1
    F.append(var_ts)
F = np.array(F,dtype = float)#shape 18*8784


X1=[]
Y1=[]
for i in range(0, F.shape[1]-9,3):
    X1.append(F[:, i:i+9].flatten())
    Y1.append([F[9, i+9]])

X1 = np.array(X1)#shape 8771*162(18*9)
Y1 = np.array(Y1)#shape 8771*1
print(X1.shape)

# %%
variables = list(train2["測項"][:18]) 
F=[]
for var in variables:
    var_list = []
    print(var)
    for index, row in train.iterrows():
        if row["測項"]==var:
            var_list.append(list(row[2:]))
    #var_list shape 366*24 
    if var == "PM2.5":
        for i in range(len(var_list)):
            for j in range(len(var_list[0])):
                if str(var_list[i][j])=='nan':
                    var_list[i][j] = 0.0
                if not is_number(var_list[i][j]):
                    for s in var_list[i][j]:
                        if s.isnumeric() or s=='.':
                            pass
                        elif s=='-':
                            var_list[i][j] = 0
                            break
                        else:
                            var_list[i][j] = var_list[i][j].replace(s,"")
        var_ts = np.array(var_list,dtype=float).flatten()
    elif var=="RAINFALL" :
  
        for i in range(len(var_list)):
            for j in range(len(var_list[0])):
                if str(var_list[i][j])=='nan':
                    var_list[i][j] = 0.0
                if is_number(var_list[i][j]):
                    pass
                if var_list[i][j]=='NR':
                    var_list[i][j] = 0.0
                if not is_number(var_list[i][j]):
                    for s in var_list[i][j]:
                        if s.isnumeric() or s=='.':
                            pass
                        elif s=='-':
                            var_list[i][j] = 0
                            break
                        else:
                            var_list[i][j] = var_list[i][j].replace(s,"")                  
        var_ts = np.array(var_list,dtype=float)#shape 366*24
        var_ts = var_ts.flatten() 
    else:
        for i in range(len(var_list)):
            for j in range(len(var_list[0])):
                
                if str(var_list[i][j])=='nan':
                    var_list[i][j] = 0.0
                if not is_number(var_list[i][j]):
                    for s in var_list[i][j]:
                        if s.isnumeric() or s=='.':
                            pass
                        elif s=='-':
                            var_list[i][j] = 0
                            break
                        else:
                            var_list[i][j] = var_list[i][j].replace(s,"")
        var_ts = np.array(var_list,dtype=float)#shape 366*24
        var_ts = var_ts.flatten()#shape 8784*1
    F.append(var_ts)
F = np.array(F,dtype = float)#shape 18*8784


X=[]
Y=[]
for i in range(0, F.shape[1]-9,3):
    X.append(F[:, i:i+9].flatten())
    Y.append([F[9, i+9]])

X = np.array(X)#shape 8775*162(18*9)
Y = np.array(Y)#shape 8775*1

# %%
X = np.concatenate((X, X1), axis=0)
Y = np.concatenate((Y, Y1), axis=0)

# %%
class Linear_Regression():
    def __init__():
        pass
        
    def error(self, X, Y):
        return Y - self.predict(X)

    def loss(self, X, Y):
        return np.sqrt(np.mean(self.error(X, Y) ** 2))
    
    def predict(self, X):
        _X = np.reshape(X, (-1, self.feature_dim))
        return np.dot(_X, self.W) + self.B
 
    def predict_test(self, X):
        #_X = self._scale(X, istrain=False)
        X = X.reshape((-1, self.feature_dim))
        return np.dot(X, self.W) + self.B



    def fit(self, _X, Y, valid, max_epoch=500000, lr=0.000001, C=0.0):
        assert _X.shape[0] == Y.shape[0]
        N = _X.shape[0]
        self.feature_dim = feature_dim = _X.shape[1]
        self.C = C
        print(_X.shape)
        X = _X
        
        if valid is not None:
            X_valid, Y_valid = valid
            X_valid = self._scale(X_valid, istrain=False)
            
        self.B = 0.0
        self.W = np.ones((self.feature_dim, 1))

        B_lr = 0.0
        W_lr = np.zeros((feature_dim, 1))
        for epoch in range(1, max_epoch+1):
            
            error = Y - self.predict(X)          
            B_grad = -np.sum(error)  / N
            W_grad = -np.dot(X.T, error) / N
            self.B = self.B - lr  * B_grad
            self.W = self.W - lr  * W_grad
            
            if epoch % 1000 == 0:
                print('[Epoch {}]: loss: {}'.format(epoch, self.loss(X, Y)))
                if valid is not None:
                    print('valid loss: {}'.format(self.loss(X_valid, Y_valid)))

# %%
model = Linear_Regression()
model.fit(X, Y, valid=None, max_epoch=100000, lr=0.000003, C=0.00001)

# %%
predict = model.predict_test(X_for_test)

# %%
for i in range(len(predict)):
    if predict[i]<0:
        predict[i] = 0

# %%
 with open('resule.csv', 'w') as f:
        print('id,value', file=f)
        for (i, p) in enumerate(predict) :
            print('id_{},{}'.format(i, p[0]), file=f)

# %% [markdown]
# # TODO #
#
# * 去掉七八月
# * shift 3 小時
# * 只做PM2.5 PM10
